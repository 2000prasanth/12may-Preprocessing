# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sb

# %%
# 1. Load the dataset
df=pd.read_csv("C:/Users/USER/Desktop/DSA course/titanic_dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2.. set index column
df.set_index('PassengerId', inplace=True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# 3. details of the dataset. It is a dataset that contains the Passenger Id, Survived or not (0=no, 1=yes), gender, age, cabin details etc

# %%
# 4. Fill missing values
df.isnull()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 887             False   False  False  False  False  False  False   False
# 888             False   False  False  False  False  False  False   False
# 889             False   False  False  False   True  False  False   False
# 890             False   False  False  False  False  False  False   False
# 891             False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked
# PassengerId
# ...

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#age
mean_age = df['Age'].mean()

# %%
df['Age'].fillna(mean_age, inplace=True)

# %%
#cabin
mode_cabin = df['Cabin'].mode()[0]

# %%
df['Cabin'].fillna(mode_cabin, inplace=True)

# %%
#embarked
mode_emb = df['Embarked'].mode()[0]

# %%
df['Embarked'].fillna(mode_emb, inplace=True)

# %%
#check and handle outliers in 3 cols
columns = ['Age', 'SibSp','Fare']

# %%
import matplotlib.pyplot as plt

# %%
for column in columns:
    df.boxplot(column=column)
    plt.show()

# %%
for column in columns:
    z_scores = np.abs((df[column] - df[column].mean()) / df[column].std())
    threshold = 3
    df = df.drop(df[z_scores > threshold].index)

# %%
for column in columns:
    q1, q3 = np.percentile(df[column], [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    df = df.drop(df[(df[column] < lower_bound) | (df[column] > upper_bound)].index)

# %%
df
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
for column in columns:
    df.boxplot(column=column)
    plt.show()

# %%
# Do min max scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Survived'] = le.fit_transform(df['Survived'])

# %%
features = df.drop('Survived', axis=1)
target = df['Survived']

scaler = MinMaxScaler()

num_features = features.select_dtypes(include=['float64', 'int64'])
num_features_scaled = scaler.fit_transform(num_features)
num_features_scaled_df = pd.DataFrame(num_features_scaled, columns=num_features.columns)

features_scaled = pd.concat([num_features_scaled_df, features.select_dtypes(exclude=['float64', 'int64'])], axis=1)

features_scaled['Survived'] = target

# %%
print(features_scaled.head())
# Out:
#    Pclass       Age  SibSp  Parch      Fare  \
# 0     1.0  0.354167    0.5    0.0  0.136535
# 1     1.0  0.437500    0.0    0.0  0.149247
# 2     0.0  0.625000    0.5    0.0  1.000000
# 3     1.0  0.625000    0.0    0.0  0.151601
# 4     1.0  0.514565    0.0    0.0  0.159290
#
#                                            Name     Sex            Ticket  \
# 0                                           NaN     NaN               NaN
# 1                       Braund, Mr. Owen Harris    male         A/5 21171
# 2                                           NaN     NaN               NaN
# 3                        Heikkinen, Miss. Laina  female  STON/O2. 3101282
# 4  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female            113803
#
#      Cabin  Embarked  Survived
# 0      NaN       NaN       NaN
# 1  B96 B98       2.0       0.0
# 2      NaN       NaN       NaN
# 3  B96 B98       2.0       1.0
# 4     C123       2.0       1.0

# %%
df
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...
